# %%
from util import *

import matplotlib.pyplot as plt

# %% [markdown]
# # SMM2CPR and CPR2SMM

# %%
SMM2CPR(10)
# Out:
# 71.75704635189999

# %%
plt.plot(np.arange(0, 20), SMM2CPR(np.arange(0, 20)))

# %%
CPR2SMM(10)
# Out:
# 0.8741610954696721

# %%
plt.plot(np.arange(0, 20), CPR2SMM(np.arange(0, 20)))

# %%
SMM2CPR(CPR2SMM(10))
# Out:
# 10.00000000000002

# %% [markdown]
# # Amortization

# %%
BAL(9, 360, 340)
# Out:
# 0.988260933783199

# %%
plt.plot(np.arange(1, 361), BAL(9, 360, 361-np.arange(1, 361)))

# %%
PMT(9, 360)
# Out:
# 0.008046226169447813

# %% [markdown]
# # PSA

# %%
PSA(10)
# Out:
# 2.0

# %%
plt.plot(np.arange(1, 361), PSA(np.arange(1, 361)))

# %% [markdown]
# # Cash Flow

# %%
from cf import PoolCashFlow

# %%
res = PoolCashFlow(9.5, 360, 360, 1)

# %% [markdown]
# # SDA

# %%
print(SDA(12))
print(SDA(30)) # peak at 0.6 from 30 to 60 months
print(SDA(48))
print(SDA(60))
print(SDA(61)) # decline starting at 61 months
print(SDA(120))# tail at 120 month
print(SDA(121))
print(SDA(348))
print(SDA(349))# zero for the last 12 months (349-360)
# Out:
# 0.24
# 0.6
# 0.6
# 0.6
# 0.5905
# 0.030000000000000027
# 0.030000000000000027
# 0.030000000000000027
# 2.7755575615628914e-17

# %%
plt.plot(np.arange(0, 360), SDA(np.arange(0, 360)))
